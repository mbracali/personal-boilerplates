# %% [markdown]
# <h1>Hermes lib test</h1>

# %% [markdown]
# <h2>Test log creation methods</h2>

# %%
# Test the import
from hermes import Hermes

# Test the creation of a simple object
log = Hermes('test_app')

# NOTE: This will result in the default behavior 
# of the module, name of files and everything else
# will be set to default constructor method

# %%
# Posting different messages to see the results
log.post("INFO", "System starting")
log.post("DONE", "Started")
log.post("WARNING", "Trying to start the log system")
log.post("LOOK", "Think it's working!")
log.post("ERROR", "Looks like this when I fail")
log.post("EASTER", "Look for some easters!")
# Out:
# 23/11/2025 01:57:30 | ROOT@TEST_APP 💬 LOG | System starting
# 23/11/2025 01:57:30 | ROOT@TEST_APP ✅ LOG | Started
# 23/11/2025 01:57:30 | ROOT@TEST_APP ⚠️ LOG | Trying to start the log system
# 23/11/2025 01:57:30 | ROOT@TEST_APP 👀 LOG | Think it's working!
# 23/11/2025 01:57:30 | ROOT@TEST_APP ⛔ LOG | Looks like this when I fail
# 23/11/2025 01:57:30 | ROOT@TEST_APP 🥚 LOG | Look for some easters!
